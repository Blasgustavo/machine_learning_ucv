# %% [markdown]
# # IF01 — Grupo 4: Bike Sharing Demand**Dataset:** `04_bike_sharing_grupo4.csv`**Variable objetivo:** `count` → regresión**Caso:** Estimar la cantidad de alquileres de bicicletas por hora en función del clima y la fecha.---### Integrantes1.2.3.4.5.

# %% [markdown]
# ## Paso 0: Importar librerías

# %% [markdown]
# ---# Bloque A — Conocer los datos

# %% [markdown]
# ## Paso 1: Cargar el CSVSubir el archivo a Colab y cargarlo como DataFrame.

# %% [markdown]
# ## Paso 2: Explorar la estructuraConocer el dataset e identificar la variable objetivo.

# %% [markdown]
# ---# Bloque B — Limpiar

# %% [markdown]
# ## Paso 3: Detectar valores faltantesDetectar nulos y decidir si eliminar o imputar.

# %% [markdown]
# ## Paso 4: Eliminar duplicadosIdentificar y eliminar filas repetidas.

# %% [markdown]
# ## Paso 5: Quitar columnas irrelevantesEliminar columnas que no aportan al modelo.

# %% [markdown]
# ## Paso 6: Verificar tipos de datosRevisar y corregir tipos incorrectos.

# %% [markdown]
# ## Paso 7: Detectar outliers en `count`Detectar valores atípicos en la variable objetivo y decidir si mantenerlos o eliminarlos.

# %% [markdown]
# ---# Bloque C — Transformar

# %% [markdown]
# ## Paso 8: Separar numéricas y categóricasSeparar las columnas según su tipo.

# %% [markdown]
# ## Paso 9: One-Hot EncodingConvertir las variables categóricas a formato numérico (0/1).

# %% [markdown]
# ---# Bloque D — Validar y guardar

# %% [markdown]
# ## Paso 10: Visualizar la variable objetivoGenerar un histograma de `count` para ver su distribución.

# %% [markdown]
# ## Paso 11: Guardar el dataset preparadoExportar el dataset listo como `bike_sharing_preparado.csv`.
